# %% [markdown]
# <a href="https://colab.research.google.com/github/cbonnin88/VifStream/blob/main/vifStream_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
from google.cloud import bigquery
import polars as pl
import plotly.express as px
import plotly.graph_objects as go
from scipy import stats

# %%
auth.authenticate_user()
print('Authenticated Successfully')
# Out:
# Authenticated Successfully

# %% [markdown]
# # **Initialize the BigQuery Client**

# %%
project_id = 'poetic-maxim-486609-e5'
client = bigquery.Client(project=project_id)

# %% [markdown]
# # **Pulling the data into a Pandas DataFrame (first) - BQ Client Standard**

# %%
query = """
SELECT * FROM `poetic-maxim-486609-e5.vifstream_dbt.fct_user_retention`
WHERE signup_date >= '2025-01-01'
"""
df_pandas_temp = client.query(query).to_dataframe()
df_fct = pl.from_pandas(df_pandas_temp)

print(f'Successfully pulled {df_fct.height} rows from BigQuery')
display(df_fct.head())
# Out:
# Successfully pulled 548986 rows from BigQuery
# shape: (5, 8)
# ┌──────────┬─────────┬──────────────┬─────────────┬─────────────┬───────────┬────────┬─────────────┐
# │ event_id ┆ user_id ┆ event_name   ┆ event_at    ┆ signup_date ┆ plan_type ┆ device ┆ days_since_ │
# │ ---      ┆ ---     ┆ ---          ┆ ---         ┆ ---         ┆ ---       ┆ ---    ┆ signup      │
# │ i64      ┆ i64     ┆ str          ┆ datetime[μs ┆ date        ┆ str       ┆ str    ┆ ---         │
# │          ┆         ┆              ┆ , UTC]      ┆             ┆           ┆        ┆ i64         │
# ╞══════════╪═════════╪══════════════╪═════════════╪═════════════╪═══════════╪════════╪═════════════╡
# │ 134920   ┆ 19389   ┆ add_to_favor ┆ 2025-12-04  ┆ 2025-01-25  ┆ free      ┆ Mobile ┆ 313         │
# │          ┆         ┆ ites         ┆ 14:07:04.03 ┆             ┆           ┆        ┆             │
# │          ┆         ┆              ┆ 8319 UTC    ┆             ┆           ┆        ┆             │
# │ 592737   ┆ 41747   ┆ add_to_favor ┆ 2025-09-19  ┆ 2025-04-02  ┆ free      ┆ Mobile ┆ 170         │
# │          ┆         ┆ ites         ┆ 15:04:54.97 ┆             ┆           ┆        ┆             │
# │          ┆         ┆              ┆ 4391 UTC    ┆             ┆           ┆        ┆             │
# │ 359413   ┆ 3974    ┆ add_to_favor ┆ 2025-12-26  ┆ 2025-10-10  ┆ free      ┆ Mobile ┆ 77          │
# │          ┆         ┆ ites         ┆ 20:16:38.55 ┆             ┆           ┆        ┆             │
# │          ┆         ┆              ┆ 4958 UTC    ┆             ┆           ┆        ┆             │
# │ 402682   ┆ 35146   ┆ add_to_favor ┆ 2026-01-05  ┆ 2026-01-18  ┆ premium   ┆ Mobile ┆ -13         │
# │          ┆         ┆ ites         ┆ 03:26:35.24 ┆             ┆           ┆        ┆             │
# │          ┆         ┆              ┆ 3159 UTC    ┆             ┆           ┆        ┆             │
# │ 769334   ┆ 44524   ┆ add_to_favor ┆ 2025-11-01  ┆ 2025-10-12  ┆ free      ┆ Mobile ┆ 20          │
# │          ┆         ┆ ites         ┆ 05:25:11.32 ┆             ┆           ┆        ┆             │
# │          ┆         ┆              ┆ 9801 UTC    ┆             ┆           ┆        ┆             │
# └──────────┴─────────┴──────────────┴─────────────┴─────────────┴───────────┴────────┴─────────────┘

# %% [markdown]
# # Cohort Analysis (Retention Heatmap)

# %%
# 2. Transform Data for Cohort Analysis
# Truncate dates to Month for grouping
df_cohort = df_fct.with_columns([
    pl.col('signup_date').cast(pl.Date).dt.truncate('1mo').alias('cohort_month'),
    pl.col('event_at').cast(pl.Date).dt.truncate('1mo').alias('activity_month')
])

df_cohort = df_cohort.with_columns([
    (((pl.col('activity_month') - pl.col('cohort_month')).dt.total_days() / 30).round(0).cast(pl.Int32)).alias('month_number')
])

# Filter out edge cases and limit to first 6 months for clarity
df_cohort = df_cohort.filter((pl.col("month_number") >= 0) & (pl.col("month_number") <= 6))

display(df_cohort.head())
# Out:
# shape: (5, 11)
# ┌──────────┬─────────┬────────────┬────────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ event_id ┆ user_id ┆ event_name ┆ event_at   ┆ … ┆ days_sinc ┆ cohort_mo ┆ activity_ ┆ month_num │
# │ ---      ┆ ---     ┆ ---        ┆ ---        ┆   ┆ e_signup  ┆ nth       ┆ month     ┆ ber       │
# │ i64      ┆ i64     ┆ str        ┆ datetime[μ ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │          ┆         ┆            ┆ s, UTC]    ┆   ┆ i64       ┆ date      ┆ date      ┆ i32       │
# ╞══════════╪═════════╪════════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 592737   ┆ 41747   ┆ add_to_fav ┆ 2025-09-19 ┆ … ┆ 170       ┆ 2025-04-0 ┆ 2025-09-0 ┆ 5         │
# │          ┆         ┆ orites     ┆ 15:04:54.9 ┆   ┆           ┆ 1         ┆ 1         ┆           │
# │          ┆         ┆            ┆ 74391 UTC  ┆   ┆           ┆           ┆           ┆           │
# │ 359413   ┆ 3974    ┆ add_to_fav ┆ 2025-12-26 ┆ … ┆ 77        ┆ 2025-10-0 ┆ 2025-12-0 ┆ 2         │
# │          ┆         ┆ orites     ┆ 20:16:38.5 ┆   ┆           ┆ 1         ┆ 1         ┆           │
# │          ┆         ┆            ┆ 54958 UTC  ┆   ┆           ┆           ┆           ┆           │
# │ 402682   ┆ 35146   ┆ add_to_fav ┆ 2026-01-05 ┆ … ┆ -13       ┆ 2026-01-0 ┆ 2026-01-0 ┆ 0         │
# │          ┆         ┆ orites     ┆ 03:26:35.2 ┆   ┆           ┆ 1         ┆ 1         ┆           │
# │          ┆         ┆            ┆ 43159 UTC  ┆   ┆           ┆           ┆           ┆           │
# │ 769334   ┆ 44524   ┆ add_to_fav ┆ 2025-11-01 ┆ … ┆ 20        ┆ 2025-10-0 ┆ 2025-11-0 ┆ 1         │
# │          ┆         ┆ orites     ┆ 05:25:11.3 ┆   ┆           ┆ 1         ┆ 1         ┆           │
# │          ┆         ┆            ┆ 29801 UTC  ┆   ┆           ┆           ┆           ┆           │
# │ 216190   ┆ 7512    ┆ add_to_fav ┆ 2025-10-19 ┆ … ┆ 168       ┆ 2025-05-0 ┆ 2025-10-0 ┆ 5         │
# │          ┆         ┆ orites     ┆ 13:25:41.8 ┆   ┆           ┆ 1         ┆ 1         ┆           │
# │          ┆         ┆            ┆ 85886 UTC  ┆   ┆           ┆           ┆           ┆           │
# └──────────┴─────────┴────────────┴────────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
# 3. Aggregate Unique Users
cohort_counts = df_cohort.group_by(['cohort_month','month_number']).agg(
    pl.col('user_id').n_unique().alias('active_users')
).sort(['cohort_month','month_number'])

display(cohort_counts.head())
# Out:
# shape: (5, 3)
# ┌──────────────┬──────────────┬──────────────┐
# │ cohort_month ┆ month_number ┆ active_users │
# │ ---          ┆ ---          ┆ ---          │
# │ date         ┆ i32          ┆ u32          │
# ╞══════════════╪══════════════╪══════════════╡
# │ 2025-01-01   ┆ 1            ┆ 1506         │
# │ 2025-01-01   ┆ 2            ┆ 1769         │
# │ 2025-01-01   ┆ 3            ┆ 1728         │
# │ 2025-01-01   ┆ 4            ┆ 1739         │
# │ 2025-01-01   ┆ 5            ┆ 1752         │
# └──────────────┴──────────────┴──────────────┘

# %%
# 4. Calucate Retention Percentage
# Get the base size for each cohort (Month 0)
cohort_sizes = cohort_counts.filter(pl.col('month_number')==0).select([
    pl.col('cohort_month'),
    pl.col('active_users').alias('cohort_size')
])


display(cohort_sizes.head())
# Out:
# shape: (5, 2)
# ┌──────────────┬─────────────┐
# │ cohort_month ┆ cohort_size │
# │ ---          ┆ ---         │
# │ date         ┆ u32         │
# ╞══════════════╪═════════════╡
# │ 2025-02-01   ┆ 1421        │
# │ 2025-03-01   ┆ 1695        │
# │ 2025-04-01   ┆ 1638        │
# │ 2025-05-01   ┆ 1756        │
# │ 2025-06-01   ┆ 1600        │
# └──────────────┴─────────────┘

# %%
# Join back and compute percentage
cohort_final = cohort_counts.join(cohort_sizes, on='cohort_month')
cohort_final = cohort_final.with_columns([
    (pl.col('active_users') / pl.col('cohort_size')* 100).round(1).alias('retention_pct')
])

display(cohort_final.head())
# Out:
# shape: (5, 5)
# ┌──────────────┬──────────────┬──────────────┬─────────────┬───────────────┐
# │ cohort_month ┆ month_number ┆ active_users ┆ cohort_size ┆ retention_pct │
# │ ---          ┆ ---          ┆ ---          ┆ ---         ┆ ---           │
# │ date         ┆ i32          ┆ u32          ┆ u32         ┆ f64           │
# ╞══════════════╪══════════════╪══════════════╪═════════════╪═══════════════╡
# │ 2025-02-01   ┆ 0            ┆ 1421         ┆ 1421        ┆ 100.0         │
# │ 2025-02-01   ┆ 1            ┆ 1592         ┆ 1421        ┆ 112.0         │
# │ 2025-02-01   ┆ 2            ┆ 1583         ┆ 1421        ┆ 111.4         │
# │ 2025-02-01   ┆ 3            ┆ 1641         ┆ 1421        ┆ 115.5         │
# │ 2025-02-01   ┆ 4            ┆ 1612         ┆ 1421        ┆ 113.4         │
# └──────────────┴──────────────┴──────────────┴─────────────┴───────────────┘

# %%
# 5. Pivot for Plotly Heatmap
pivot_pl = cohort_final.pivot(
    index='cohort_month',
    on='month_number',
    values='retention_pct'
).sort('cohort_month')

display(pivot_pl.head())
# Out:
# shape: (5, 8)
# ┌──────────────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┐
# │ cohort_month ┆ 0     ┆ 1     ┆ 2     ┆ 3     ┆ 4     ┆ 5     ┆ 6     │
# │ ---          ┆ ---   ┆ ---   ┆ ---   ┆ ---   ┆ ---   ┆ ---   ┆ ---   │
# │ date         ┆ f64   ┆ f64   ┆ f64   ┆ f64   ┆ f64   ┆ f64   ┆ f64   │
# ╞══════════════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╡
# │ 2025-02-01   ┆ 100.0 ┆ 112.0 ┆ 111.4 ┆ 115.5 ┆ 113.4 ┆ 111.8 ┆ 114.2 │
# │ 2025-03-01   ┆ 100.0 ┆ 99.5  ┆ 101.5 ┆ 98.6  ┆ 99.8  ┆ 99.4  ┆ 99.8  │
# │ 2025-04-01   ┆ 100.0 ┆ 103.4 ┆ 98.0  ┆ 101.2 ┆ 102.1 ┆ 97.8  ┆ 100.4 │
# │ 2025-05-01   ┆ 100.0 ┆ 98.3  ┆ 97.7  ┆ 99.1  ┆ 100.2 ┆ 100.2 ┆ 98.6  │
# │ 2025-06-01   ┆ 100.0 ┆ 101.2 ┆ 101.2 ┆ 100.0 ┆ 101.5 ┆ 101.2 ┆ 101.2 │
# └──────────────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┘

# %%
# Convert to Pandas fro Plotly Compatibility
plot_df = pivot_pl.to_pandas().set_index('cohort_month')

# %%
fig_cohort = go.Figure(data=go.Heatmap(
    z=plot_df.values,
    x=[f'Month {int(c)}' for c in plot_df.columns],
    y=plot_df.index.astype(str),
    colorscale='Blues',
    text=plot_df.values,
    texttemplate='%{text}%',
    hoverinfo='z'
))

fig_cohort.update_layout(
    title='VifStream: Monthly User Retention (%)',
    xaxis_title='Months After Signup',
    yaxis_title='Signup Month',
    template='plotly_white'
)

fig_cohort.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e86c193d-6786-4147-a8e0-0abb1b38d760" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e86c193d-6786-4147-a8e0-0abb1b38d760")) {                    Plotly.newPlot(                        "e86c193d-6786-4147-a8e0-0abb1b38d760",                        [{"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"hoverinfo":"z","text":[[100.0,112.0,111.4,115.5,113.4,111.8,114.2],[100.0,99.5,101.5,98.6,99.8,99.4,99.8],[100.0,103.4,98.0,101.2,102.1,97.8,100.4],[100.0,98.3,97.7,99.1,100.2,100.2,98.6],[100.0,101.2,101.2,100.0,101.5,101.2,101.2],[100.0,102.4,99.1,100.8,99.6,102.4,100.2],[100.0,97.6,101.8,99.1,99.5,101.1,30.8],[100.0,101.5,97.3,99.3,101.7,30.3,null],[100.0,101.3,100.8,100.7,31.5,null,null],[100.0,101.0,100.5,28.8,null,null,null],[100.0,102.4,29.7,null,null,null,null],[100.0,30.5,null,null,null,null,null],[100.0,null,null,null,null,null,null]],"texttemplate":"%{text}%","x":["Month 0","Month 1","Month 2","Month 3","Month 4","Month 5","Month 6"],"y":["2025-02-01","2025-03-01","2025-04-01","2025-05-01","2025-06-01","2025-07-01","2025-08-01","2025-09-01","2025-10-01","2025-11-01","2025-12-01","2026-01-01","2026-02-01"],"z":[[100.0,112.0,111.4,115.5,113.4,111.8,114.2],[100.0,99.5,101.5,98.6,99.8,99.4,99.8],[100.0,103.4,98.0,101.2,102.1,97.8,100.4],[100.0,98.3,97.7,99.1,100.2,100.2,98.6],[100.0,101.2,101.2,100.0,101.5,101.2,101.2],[100.0,102.4,99.1,100.8,99.6,102.4,100.2],[100.0,97.6,101.8,99.1,99.5,101.1,30.8],[100.0,101.5,97.3,99.3,101.7,30.3,null],[100.0,101.3,100.8,100.7,31.5,null,null],[100.0,101.0,100.5,28.8,null,null,null],[100.0,102.4,29.7,null,null,null,null],[100.0,30.5,null,null,null,null,null],[100.0,null,null,null,null,null,null]],"type":"heatmap"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666 ...

# %% [markdown]
# # **Data Visualization with Plotly**

# %%
# Definin the stages of the funnel
stages = ['app_open','search','paywall_view','channel_tune_in']

# %%
funnel_counts = []
for stage in stages:
  count = df_fct.filter(pl.col('event_name')== stage).select(pl.col('user_id').n_unique()).item()
  funnel_counts.append(count)

# %%
fig_funnel = px.funnel(
    data_frame={'Stage':stages,'Users':funnel_counts},
    y='Stage',
    x='Users',
    title='VifStream Onboarding Conversion Funnel',
    color_discrete_sequence=px.colors.qualitative.Prism
)

fig_funnel.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6ca1314c-8223-46e7-8155-8b7d8f8eb470" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ca1314c-8223-46e7-8155-8b7d8f8eb470")) {                    Plotly.newPlot(                        "6ca1314c-8223-46e7-8155-8b7d8f8eb470",                        [{"hovertemplate":"Users=%{x}\u003cbr\u003eStage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"rgb(95, 70, 144)"},"name":"","orientation":"h","showlegend":false,"x":[43530,40769,35847,47563],"xaxis":"x","y":["app_open","search","paywall_view","channel_tune_in"],"yaxis":"y","type":"funnel"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","m ...

# %% [markdown]
# # **Segmenting 'Tune-In' Behavior**

# %%
# Aggregating events by device and type
device_engagement = df_fct.group_by(['device','event_name']).agg(
    pl.count('event_id').alias('event_count')
).sort('event_count',descending=True)

display(device_engagement.head())
# Out:
# shape: (5, 3)
# ┌─────────┬─────────────────┬─────────────┐
# │ device  ┆ event_name      ┆ event_count │
# │ ---     ┆ ---             ┆ ---         │
# │ str     ┆ str             ┆ u32         │
# ╞═════════╪═════════════════╪═════════════╡
# │ Mobile  ┆ channel_tune_in ┆ 187826      │
# │ AppleTV ┆ channel_tune_in ┆ 76650       │
# │ Mobile  ┆ app_open        ┆ 75338       │
# │ SmartTV ┆ channel_tune_in ┆ 74329       │
# │ Mobile  ┆ search          ┆ 56020       │
# └─────────┴─────────────────┴─────────────┘

# %%
fig_engagement = px.bar(
    device_engagement.to_pandas(),
    x='device',
    y='event_count',
    color='event_name',
    barmode='group',
    title='VifStream Engagement: Event Distribution by Device',
    template='plotly_white',
    labels={'event_count':'Event','device':'Device Type'}
)

fig_engagement.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e2f4cb57-3040-4b6e-8d20-de31f4a393b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2f4cb57-3040-4b6e-8d20-de31f4a393b2")) {                    Plotly.newPlot(                        "e2f4cb57-3040-4b6e-8d20-de31f4a393b2",                        [{"alignmentgroup":"True","hovertemplate":"event_name=channel_tune_in\u003cbr\u003eDevice Type=%{x}\u003cbr\u003eEvent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"channel_tune_in","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"channel_tune_in","offsetgroup":"channel_tune_in","orientation":"v","showlegend":true,"textposition":"auto","x":["Mobile","AppleTV","SmartTV","Web"],"xaxis":"x","y":[187826,76650,74329,37196],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"event_name=app_open\u003cbr\u003eDevice Type=%{x}\u003cbr\u003eEvent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"app_open","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"app_open","offsetgroup":"app_open","orientation":"v","showlegend":true,"textposition":"auto","x":["Mobile","AppleTV","SmartTV","Web"],"xaxis":"x","y":[75338,30480,29923,14755],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"event_name=search\u003cbr\u003eDevice Type=%{x}\u003cbr\u003eEvent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"search","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"search","offsetgroup":"search","orientation":"v","showlegend":true,"textposition":"auto","x":["Mobile","AppleTV","SmartTV","Web"],"xaxis":"x","y":[56020,22835,22513,11130],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"event_name=paywall_view\u003cbr\u003eDevice Type=%{x}\u003cbr\u003eEvent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"paywall_view","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"paywall_view","offsetgroup":"paywall_view","orientation":"v","showlegend":true,"textposition":"auto","x":["Mobile","AppleTV","SmartTV","Web"],"xaxis":"x","y":[37697,15184,14859,7262],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"event_name=add_to_favorites\u003cbr\u003eDevice Type=%{x}\u003cbr\u003eEvent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"add_to_favorites","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"add_to_favorites","offsetgroup":"add_to_favorites","orientation":"v","showlegend":true,"textposition":"auto","x":["Mobile","AppleTV","SmartTV","Web"],"xaxis":"x","y":[18835,7707,7384,3734],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888, ...

# %% [markdown]
# # **Average Time to 'Aha' Moment**

# %%
# Filter for first tune-in only
first_tune_in = df_fct.filter(pl.col('event_name') == 'channel_tune_in').group_by('user_id').agg(pl.col('days_since_signup').min().alias('first_tune_day'), pl.col('plan_type').first())

display(first_tune_in)
# Out:
# shape: (47_563, 3)
# ┌─────────┬────────────────┬───────────┐
# │ user_id ┆ first_tune_day ┆ plan_type │
# │ ---     ┆ ---            ┆ ---       │
# │ i64     ┆ i64            ┆ str       │
# ╞═════════╪════════════════╪═══════════╡
# │ 35014   ┆ 225            ┆ free      │
# │ 18451   ┆ 72             ┆ free      │
# │ 42528   ┆ 375            ┆ basic     │
# │ 20684   ┆ 54             ┆ free      │
# │ 4356    ┆ 20             ┆ free      │
# │ …       ┆ …              ┆ …         │
# │ 30168   ┆ 53             ┆ basic     │
# │ 40788   ┆ 70             ┆ basic     │
# │ 43117   ┆ 46             ┆ free      │
# │ 2583    ┆ 44             ┆ free      │
# │ 8470    ┆ 164            ┆ free      │
# └─────────┴────────────────┴───────────┘

# %%
# Calculate average per plan
aha_moment_stats = first_tune_in.group_by('plan_type').agg(
    pl.col('first_tune_day').mean().round(0).alias('avg_days_to_tune_in')
)
display(aha_moment_stats)
# Out:
# shape: (3, 2)
# ┌───────────┬─────────────────────┐
# │ plan_type ┆ avg_days_to_tune_in │
# │ ---       ┆ ---                 │
# │ str       ┆ f64                 │
# ╞═══════════╪═════════════════════╡
# │ free      ┆ 132.0               │
# │ premium   ┆ 131.0               │
# │ basic     ┆ 129.0               │
# └───────────┴─────────────────────┘

# %%
fig_aha = px.bar(
    aha_moment_stats.to_pandas(),
    x='plan_type',
    y='avg_days_to_tune_in',
    color='plan_type',
    title='Average Days to First Content Engagment by Plan',
    labels={'plan_type':'Subscription Type','avg_days_to_tune_in':'Average Days to Tune-In'},
    text_auto='.0f',
    template='plotly_dark'
)

fig_aha.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="533dceb8-bf78-429c-9d99-88d400ce5638" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("533dceb8-bf78-429c-9d99-88d400ce5638")) {                    Plotly.newPlot(                        "533dceb8-bf78-429c-9d99-88d400ce5638",                        [{"alignmentgroup":"True","hovertemplate":"Subscription Type=%{x}\u003cbr\u003eAverage Days to Tune-In=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"free","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"free","offsetgroup":"free","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.0f}","x":["free"],"xaxis":"x","y":[132.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Subscription Type=%{x}\u003cbr\u003eAverage Days to Tune-In=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"premium","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"premium","offsetgroup":"premium","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.0f}","x":["premium"],"xaxis":"x","y":[131.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Subscription Type=%{x}\u003cbr\u003eAverage Days to Tune-In=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"basic","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"basic","offsetgroup":"basic","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.0f}","x":["basic"],"xaxis":"x","y":[129.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666 ...

# %% [markdown]
# # **Distribution**

# %%
aha_distribution = df_fct.filter(pl.col('event_name')== 'channel_tune_in').group_by('user_id').agg([
    pl.col('days_since_signup').min().alias('days_to_aha'),
    pl.col('plan_type').first()
])

display(aha_distribution.head())
# Out:
# shape: (5, 3)
# ┌─────────┬─────────────┬───────────┐
# │ user_id ┆ days_to_aha ┆ plan_type │
# │ ---     ┆ ---         ┆ ---       │
# │ i64     ┆ i64         ┆ str       │
# ╞═════════╪═════════════╪═══════════╡
# │ 13399   ┆ 281         ┆ free      │
# │ 4389    ┆ 33          ┆ free      │
# │ 4261    ┆ 0           ┆ free      │
# │ 35055   ┆ 269         ┆ basic     │
# │ 13860   ┆ 318         ┆ basic     │
# └─────────┴─────────────┴───────────┘

# %%
fig_hist = px.histogram(
    aha_distribution.to_pandas(),
    x='days_to_aha',
    color='plan_type',
    nbins=30,
    title='Distribution of Days to Aha! Moments (First Tune-In)',
    labels={'days_to_aha':'Days Since Signup','count':'Number of Users'},
    barmode='overlay',
    template='plotly_white'
)

fig_hist.add_vline(x=aha_distribution['days_to_aha'].mean(),line_dash='dash',line_color='red',annotation_text='Average')

fig_hist.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ec4af3f2-8b29-4d47-bd0e-fcf53d60a6dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec4af3f2-8b29-4d47-bd0e-fcf53d60a6dc")) {                    Plotly.newPlot(                        "ec4af3f2-8b29-4d47-bd0e-fcf53d60a6dc",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"plan_type=free\u003cbr\u003eDays Since Signup=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"free","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"free","nbinsx":30,"offsetgroup":"free","orientation":"v","showlegend":true,"x":[281,33,0,42,28,48,65,122,102,393,26,22,342,373,188,47,276,38,95,317,63,41,64,204,9,167,37,407,98,23,23,32,87,13,177,337,75,32,12,27,9,12,403,300,43,292,150,34,179,197,19,24,368,2,24,22,27,1,97,25,222,277,405,10,140,363,61,24,55,371,216,76,12,232,24,26,1,85,371,29,110,84,257,3,311,35,1,348,278,340,8,88,6,4,109,228,268,373,40,472,178,196,20,18,117,140,13,52,308,10,110,13,34,85,428,109,96,93,202,101,114,3,397,14,356,3,17,81,132,60,23,25,167,279,25,47,2,82,91,339,55,7,28,12,291,58,353,403,368,316,194,9,336,36,10,13,237,3,6,10,120,0,129,31,8,121,38,22,300,81,38,8,71,27,173,201,340,113,35,20,14,59,29,17,12,117,50,9,5,154,373,94,20,18,0,362,379,4,152,298,150,249,21,363,212,266,34,111,202,44,141,159,27,189,100,340,112,114,25,18,17,373,29,110,24,25,48,292,193,159,67,140,12,12,410,60,334,1,9,376,324,254,332,229,12,30,304,13,15,359,6,150,205,181,340,165,107,77,316,21,29,131,16,183,25,80,57,97,4,167,12,9,210,51,304,300,40,302,3,80,334,23,49,56,1,10,9,143,112,447,69,12,242,21,10,321,254,122,67,3,21,8,43,188,337,85,241,264,65,219,40,128,33,130,36,153,138,53,41,1,251,136,29,137,359,41,399,471,292,278,110,31,8,349,319,287,87,65,257,24,127,48,29,42,9,47,136,248,31,59,190,255,95,26,29,3,365,39,84,306,389,111,3,126,52,138,22,46,25,400,62,38,263,24,142,215,19,286,9,95,196,15,1,141,19,10,112,7,9,293,59,35,108,23,227,333,102,104,100,6,16,215,212,338,303,96,71,130,4,66,43,2,108,255,35,250,328,30,348,161,398,32,180,13,151,257,59,68,217,383,377,9,2,18,21,48,15,123,247,18,211,28,311,16,17,8,29,391,403,37,262,12,413,208,116,311,277,61,48,7,3,6,111,140,8,212,30,153,28,407,162,49,163,34,193,25,39,62,261,14,1,30,2,52,356,349,9,266,126,126,367,311,161,353,20,118,5,291,72,217,23,23,46,23,9,20,104,61,19,51,14,168,30,61,232,245,154,321,171,381,49,1,287,42,15,289,379,354,184,68,1,64,33,4,30,45,0,53,28,366,105,65,25,4,15,265,61,19,117,14,117,65,366,2,94,133,258,1,37,1,12,56,344,137,392,156,12,1,35,314,330,85,187,60,308,115,151,90,338,10,160,96,4,21,25,2,37,293,243,35,2,318,23,58,258,7,154,386,91,2,410,45,92,11,34,29,25,12,3,144,0,298,315,294,228,15,71,12,155,14,4,379,138,1,314,23,71,3,0,438,345,234,15,9,19,1,229,66,12,117,65,312,73,61,33,69,243,88,131,15,83,20,34,119,149,398,266,31,290,26,12,393,486,9,274,276,30,53,16,28,1,245,2,34,55,222,231,58,23,41,311,59,14,14,47,17,33,108,42,19,49,315,5,22,179,299,19,32,16,6,385,186,121,126,319,157,25,26,332,51,321,340,130,78,2,363,22,15,4,245,303,294,21,57,34,1,18,134,20,0,373,126,25,94,87,59,345,47,13,4,110,301,82,29,23,43,25,85,3,64,348,211,2,24,286,197,66,154,145,323,144,144,291,77,244,221,5,109,53,67,42,48,37,104,187,316,92,20,414,258,36,30,6,275,18,39,5,416,105,23,33,30,33,187,59,185,212,9,64,477,66,220,376,6,7,97,34,179,262,60,261,16,4,240,8,130,29,16,70,93,23,165,11,318,117,182,358,222,27,211,207,348,318,302,274,143,346,20,49,376,2,146,10,305,336,377,12,12,139,130,89,195,459,120,109,131,90,206,104,353,3,36,364,39,41,106,322,17,376,79,14,1,62,39,460,29,36,438,311,28,49,99,284,237,119,348,4,4,352,94,42,101,51,0,187,136,205,31,4,32,135,341,63,25,172,144,193,259,410,459,2,91,67,272,31,59,17,375,5,78,176,75,139,6,69,151,261,6, ...
